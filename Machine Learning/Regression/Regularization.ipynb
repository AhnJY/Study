# %%
from IPython.display import Image
Image('regularization.jpg', width = 400)

# %% [markdown]
# ## Regularization
# - over-fitting 문제를 해결하기 위해 등장한 회귀 규제방법
# - 비용 함수에 alpha 값으로 페널티를 부여해 회귀 계수 값의 크기를 감소시켜 과적합을 개선하는 방식
# - L1 방식과 L2 방식이 존재함
# - 총합의 수를 조절하기 위해 가중치 alpha에 따른 Weight 값을 변화할 수 밖에 없는 점을 이용
#
# ### 1. Lasso 라쏘
# - 이 경우 alpha값이 커지면 영향력이 크지 않은 feature를 0으로 변환하는 문제가 발생함
# - feature selection과 비슷한 현상
#
# ### 2. Ridge 릿지
#
# ### 3. Elastic Net 엘라스틱넷
# - L1, L2를 함께 결합한 모델
# - 주로 피처가 많은 데이터 세트에서 적용되며 L1 규제로 피처의 개수를 줄임과 동시에 L2 규제로 계수 값의 크기를 조정함

# %% [markdown]
# ### Ridge Regression
