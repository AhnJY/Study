# %% [markdown]
# ## 목표
# - 앞선 데이터를 기반으로 Class의 이상치(1)을 분류
#
# ### 1. EDA
# - 데이터 전반을 분석
# - 전처리 방향 도출
#
# ### 2. Data Preprocessing
# - log1p( )
# - StandardScaler( )
# - percentile( )
#
# ### 3. Predict

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier

# %%
fpath = '../../Downloads/creditcard.csv'
card_df = pd.read_csv(fpath)
card_df.head(3)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
card_df.shape
# Out:
# (284807, 31)

# %%
card_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %% [markdown]
# ### EDA

# %%
card_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
card_df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# - 1의  수가 매우 적음을 알 수 있음
# - 오버샘플링 필요

# %%
for idx in card_df.columns :
    print(f"{idx} :  ",len(card_df[idx].value_counts()))
# Out:
# Time :   124592
# V1 :   275663
# V2 :   275663
# V3 :   275663
# V4 :   275663
# V5 :   275663
# V6 :   275663
# V7 :   275663
# V8 :   275663
# V9 :   275663
# V10 :   275663
# V11 :   275663
# V12 :   275663
# V13 :   275663
# V14 :   275663
# V15 :   275663
# V16 :   275663
# V17 :   275663
# V18 :   275663
# V19 :   275663
# V20 :   275663
# V21 :   275663
# V22 :   275663
# V23 :   275663
# V24 :   275663
# V25 :   275663
# V26 :   275663
# V27 :   275663
# V28 :   275663
# Amount :   32767
# Class :   2

# %% [markdown]
# - 대부분의 column들이 분산된 값을 가지고 있음

# %%
time = card_df['Time'].value_counts().to_frame().reset_index().rename(columns = {'Time':'cnt', 'index' : 'Time'})
time
# Out:
#             Time  cnt
# 0       163152.0   36
# 1        64947.0   26
# 2        68780.0   25
# 3         3767.0   21
# 4         3770.0   20
# ...          ...  ...
# 124587  127750.0    1
# 124588   62260.0    1
# 124589   62259.0    1
# 124590  127753.0    1
# 124591  172792.0    1
#
# [124592 rows x 2 columns]

# %%
time[time.cnt == 1].count()
# Out:
# Time    45163
# cnt     45163
# dtype: int64

# %% [markdown]
# - Time의 value가 통일되지 못하고 분산되어 있음
# - Time의 1/3이 단 한개의 값만을 가짐

# %%
print('Time min : {0}, Time max : {1}'.format(time.Time.min(), time.Time.max()))
# Out:
# Time min : 0.0, Time max : 172792.0

# %%
import seaborn as sns

plt.figure(figsize = (10, 6))
plt.xticks(range(0, 180000, 10000), rotation = 60)
sns.histplot(card_df['Time'], bins = 100, kde = True)
plt.show()

# %%
print('Amount min : {0}, Amount max : {1}'.format(card_df.Amount.min(), card_df.Amount.max()))
# Out:
# Amount min : 0.0, Amount max : 25691.16

# %%
plt.figure(figsize = (10, 6))
plt.xticks(range(0, 26000, 1000), rotation = 60)
sns.histplot(card_df['Amount'], bins = 100, kde = True)
plt.show()

# %% [markdown]
# - Time은 특정한 양상을 보이지 않고, Amount는 적은 값에 데이터가 몰려있음
# - Amount에 대한 데이터 가공 필요
# - 데이터 분포를 종모양으로 만들기 위한 방안 : 로그함수(log1p)
# - 이후 첨도가 크다면 이를 줄이기 위한 방안 : 표준화(StandardScaler)

# %%
corr = card_df.corr()
corr.abs().Class.sort_values(ascending=False)
# Out:
# Class     1.000000
# V17       0.326481
# V14       0.302544
# V12       0.260593
# V10       0.216883
# V16       0.196539
# V3        0.192961
# V7        0.187257
# V11       0.154876
# V4        0.133447
# V18       0.111485
# V1        0.101347
# V9        0.097733
# V5        0.094974
# V2        0.091289
# V6        0.043643
# V21       0.040413
# V19       0.034783
# V20       0.020090
# V8        0.019875
# V27       0.017580
# Time      0.012323
# V28       0.009536
# V24       0.007221
# Amount    0.005632
# V13       0.004570
# V26       0.004455
# V15       0.004223
# V25       0.003308
# V23       0.002685
# V22       0.000805
# Name: Class, dtype: float64

# %%
import seaborn as sns

sns.heatmap(card_df.corr(), annot = True, cmap = 'RdYlGn', linewidths = 0.2)
fig = plt.gcf()
fig.set_size_inches(20, 15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
plt.show()

# %% [markdown]
# - 상관분석결과 Class와 가장 연관있는 feature의 값이 V17, 0.326481 이므로 높은 상관게수를 가지고 있지 않음
# - feature selection을 사용하여 columns의 수를 효율적으로 사용하는 과정이 필요

# %% [markdown]
# ### Data Preprocessing
# - 로그변환
# - 표준화

# %%
card = card_df.copy()
amount_n = np.log1p(card['Amount'])
card.insert(0, 'Amount_log', amount_n)
card.drop('Amount', axis = 1, inplace = True)

# %%
card.Amount_log
# Out:
# 0         5.014760
# 1         1.305626
# 2         5.939276
# 3         4.824306
# 4         4.262539
#             ...
# 284802    0.570980
# 284803    3.249987
# 284804    4.232366
# 284805    2.397895
# 284806    5.384495
# Name: Amount_log, Length: 284807, dtype: float64

# %%
plt.figure(figsize = (8, 4))
sns.histplot(card['Amount_log'], bins = 50, kde = True)
plt.show()

# %%
#첨도가 그리 크지 않으니 표준화 할 필요는 없지만 만약 하게 된다면 다음과 같다.

from sklearn.preprocessing import StandardScaler

card = card_df.copy()
scaler = StandardScaler()
amount_n = scaler.fit_transform(card['Amount'].values.reshape(-1, 1))
card.insert(0, 'Amount_Scaled', amount_n)
card.drop('Amount', axis = 1, inplace = True)

# %%
card.Amount_Scaled
# Out:
# 0         0.244964
# 1        -0.342475
# 2         1.160686
# 3         0.140534
# 4        -0.073403
#             ...
# 284802   -0.350151
# 284803   -0.254117
# 284804   -0.081839
# 284805   -0.313249
# 284806    0.514355
# Name: Amount_Scaled, Length: 284807, dtype: float64

# %% [markdown]
# - 다시 한 번 상관관계 분석
# - 상위 10퍼센트에 대한 outlier 레코드 확인 후 처리

# %%
card.corr().abs().Class.to_frame().sort_values(by = 'Class', ascending = False)
# Out:
#                Class
# Class       1.000000
# V17         0.326481
# V14         0.302544
# V12         0.260593
# V10         0.216883
# V16         0.196539
# V3          0.192961
# V7          0.187257
# V11         0.154876
# V4          0.133447
# V18         0.111485
# V1          0.101347
# V9          0.097733
# V5          0.094974
# V2          0.091289
# V6          0.043643
# V21         0.040413
# V19         0.034783
# V20         0.020090
# V8          0.019875
# V27         0.017580
# Time        0.012323
# V28         0.009536
# Amount_log  0.008326
# V24         0.007221
# V13         0.004570
# V26         0.004455
# V15         0.004223
# V25         0.003308
# V23         0.002685
# V22         0.000805

# %% [markdown]
# - 학습 데이터와 테스트 데이터 분할
# - 학습 데이터는 이상치 제거 후 학습에 사용

# %%
def get_outlier(df = None, column = None, weight = 1.5) :
    #fraud에 해당하는 column 데이터만 추출.
    #1/4분위와 3/4분위 지점을 np.percentile로 구함
    fraud = df[df['Class'] == 1][column]
    quantile_25 = np.percentile(fraud.values, 25)
    quantile_75 = np.percentile(fraud.values, 75)
    
    #IQR을 구하고, IQR에 1.5를 곱하여 최대값 최소값 지점 계산
    iqr = quantile_75 - quantile_25
    iqr_weight = iqr * weight
    lowest_val = quantile_25 - iqr_weight
    highest_val = quantile_75 + iqr_weight
    
    outlier_index = fraud[(fraud<lowest_val) | (fraud>highest_val)].index
    return outlier_index

# %%
def data_preprocessed(df = None):
    df_copy = df.copy()
    amount_n = np.log1p(df_copy['Amount'])
    df_copy.insert(0, 'Amount_log', amount_n)
    df_copy.drop('Amount', axis= 1, inplace = True)
    
    outlier_index = get_outlier(df = df_copy, column = 'V17', weight = 1.5) #가장 상관계수가 높았던 column을 기준으로 삭제
    df_copy.drop(outlier_index, axis = 0, inplace = True)
        
    return df_copy

# %%
def get_train_test_dataset(df = None):
    df = data_preprocessed(df)
    df_copy = df.copy()
    
    X_feature = df_copy.iloc[:, :-1]
    y_target = df_copy.iloc[:, -1]
    
    X_train, X_test, y_train, y_test = train_test_split(X_feature, y_target, test_size = 0.3, 
                                                        random_state = 0, stratify = y_target)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = get_train_test_dataset(card_df)

# %%
def get_clf_eval(y_test, pred = None, pred_proba = None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    
    roc_auc = roc_auc_score(y_test, pred_proba)
    
    print('confusion matrix')
    print(confusion)
    
    print('accuracy : {0:.4f}, precision : {1:.4f}, recall : {2:.4f}, f1 : {3:.4f}, roc_auc : {4:.4f}'.format(
    accuracy, precision, recall, f1, roc_auc))

# %%
def get_model_train_eval(model, ftr_train = None, ftr_test = None, tgt_train = None, tgt_test = None):
    model.fit(ftr_train, tgt_train)
    pred = model.predict(ftr_test)
    pred_proba = model.predict_proba(ftr_test)[:, 1]
    get_clf_eval(tgt_test, pred, pred_proba)

# %%
print('---Logistic Regression---')
lr_clf = LogisticRegression(max_iter = 1000)
get_model_train_eval(lr_clf, X_train, X_test, y_train, y_test)

print('---LightGBM---')
lgbm_clf = LGBMClassifier(n_estimators =1000, num_leaves = 64, n_jobs = -1, boost_from_average = False)
get_model_train_eval(lgbm_clf, X_train, X_test, y_train, y_test)
# Out:
# ---Logistic Regression---
# confusion matrix
# [[85276    19]
#  [   55    93]]
# accuracy : 0.9991, precision : 0.8304, recall : 0.6284, f1 : 0.7154, roc_auc : 0.9414
# ---LightGBM---
# confusion matrix
# [[85291     4]
#  [   35   113]]
# accuracy : 0.9995, precision : 0.9658, recall : 0.7635, f1 : 0.8528, roc_auc : 0.9815

# %% [markdown]
# - SMOTE OverSampling

# %%
import imblearn

print(imblearn.__version__)
# Out:
# 0.7.0

# %%
y_train.value_counts()
# Out:
# 0    199020
# 1       344
# Name: Class, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state = 0)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트 : ', X_train.shape, y_train.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트 : ', X_train_over.shape, y_train_over.shape)
print('SMOTE 적용 후 레이블 값 분포 : \n', pd.Series(y_train_over).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 :  (199364, 30) (199364,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트 :  (398040, 30) (398040,)
# SMOTE 적용 후 레이블 값 분포 :
#  0    199020
# 1    199020
# Name: Class, dtype: int64

# %%
print('---Logistic Regression---')
lr_clf = LogisticRegression(max_iter = 1000)
get_model_train_eval(lr_clf, X_train_over, X_test, y_train_over, y_test)

print('---LightGBM---')
lgbm_clf = LGBMClassifier(n_estimators =1000, num_leaves = 64, n_jobs = -1, boost_from_average = False)
get_model_train_eval(lgbm_clf, X_train_over, X_test, y_train_over, y_test)
# Out:
# ---Logistic Regression---
# confusion matrix
# [[83722  1573]
#  [   19   129]]
# accuracy : 0.9814, precision : 0.0758, recall : 0.8716, f1 : 0.1395, roc_auc : 0.9565
# ---LightGBM---
# confusion matrix
# [[85284    11]
#  [   28   120]]
# accuracy : 0.9995, precision : 0.9160, recall : 0.8108, f1 : 0.8602, roc_auc : 0.9842

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_recall_curve
# %matplotlib inline

def precision_recall_curve_plot(y_test, pred_proba_c1):
    # threshold ndarray와 이 threahold에 따른 정밀도, 재현율 ndarray 추출
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
    
    # x : threshold, y : precision&recall
    plt.figure(figsize = (8, 6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle = '--', label = 'precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label = 'recall')
    
    # threshold값 X축의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value')
    plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()

# %%
precision_recall_curve_plot(y_test, lr_clf.predict_proba(X_test)[:, 1])

# %%
precision_recall_curve_plot(y_test, lgbm_clf.predict_proba(X_test)[:, 1])
